# %%
import os
import pickle
import pandas as pd
os.chdir('/Users/bellepeng/Desktop/Metis/Projects/Project_AirBNB/data')

# %%
with open('sentiments.pkl', 'rb') as file:
    sentiments = pickle.load(file)

print(sentiments.shape)
sentiments.head()
# Out:
# (74109, 6)
#      listing_id         id       date  \
# 131         958  249775050 2018-04-02
# 132         958  252914991 2018-04-12
# 133         958  256377297 2018-04-22
# 134         958  267480372 2018-05-21
# 135         958  268720981 2018-05-25
#
#                                               comments  sentiment_score  \
# 131  A perfect spot for a mid-to-long break. Near s...         0.330833
# 132  We had a fantastic stay with Holly, her place ...         0.295238
# 133  Great Air BnB in a handy position in v nice su...         0.412698
# 134  Great place to stay and explore San Francisco....         0.548333
# 135  Holly's place was great. Clean, sunny and well...         0.448958
#
#      sentiment_score_scaled
# 131                6.654167
# 132                6.476190
# 133                7.063492
# 134                7.741667
# 135                7.244792

# %%
sentiments.to_csv('sentiments.csv')

# %%
with open('summary_df.pkl', 'rb') as file:
    summary_df = pickle.load(file)

print(summary_df.shape)
summary_df.head()
# Out:
# (5457, 3)
#   listing_id                                     summaryLexRank  \
# 0        958  We had a fantastic stay with Holly, her place ...
# 1       5858  We had a lovely stay in SF- the city is gorgeo...
# 2       7918  The room I stayed in was fantastic with a grea...
# 3       8142  This was perfect for what I needed: a cheap pl...
# 4       8339  Rosy and her family were gone for most of our ...
#
#                                           summaryLSA
# 0  Near several good cafes, a dog park with happy...
# 1  We had a wonderful time staying at Philip and ...
# 2  Are is safe and quiet but a few blocks up from...
# 3  Overall a great, extremely easy, no hassle exp...
# 4  With amazing generosity Rosy never made us fee...

# %%
summary_df.to_csv('review_summaries.csv')

# %%
np.sqrt(0.13833011471128973)
np.sqrt(0.25517167252276335)
# Out:
# 0.5051451994454301

# %% [markdown]
# ### Select vars from original data for display purposes

# %%
listings_sf = pd.read_csv('SF/201808/listings_201808.csv')
print(listings_sf.shape)
listings_sf.head(3)
# Out:
# (6633, 96)
#      id                        listing_url       scrape_id last_scraped  \
# 0   958   https://www.airbnb.com/rooms/958  20180806171132   2018-08-06
# 1  5858  https://www.airbnb.com/rooms/5858  20180806171132   2018-08-06
# 2  7918  https://www.airbnb.com/rooms/7918  20180806171132   2018-08-06
#
#                                          name  \
# 0         Bright, Modern Garden Unit - 1BR/1B
# 1                          Creative Sanctuary
# 2  A Friendly Room - UCSF/USF - San Francisco
#
#                                              summary  \
# 0  Our bright garden unit overlooks a grassy back...
# 1                                                NaN
# 2  Nice and good public transportation.  7 minute...
#
#                                                space  \
# 0  Newly remodeled, modern, and bright garden uni...
# 1  We live in a large Victorian house on a quiet ...
# 2  Room rental-sunny view room/sink/Wi Fi (inner ...
#
# ...

# %%
listings_sf.iloc[:2, 90:110]
# Out:
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     moderate
# 1                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               1               1.38
# 1                               1               0.99

# %%
vars=['name', 'summary', 'space', 'description', 'neighborhood_overview', 'notes', 'house_rules',
       'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_is_superhost', 
      'host_thumbnail_url', 'host_picture_url', 'neighbourhood_cleansed',
       'city', 'state', 'zipcode', 'country', 'latitude', 'longitude',
       'property_type', 'room_type', 'accommodates',
       'bathrooms', 'bedrooms', 'beds', 'bed_type', 
       'price', 'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
       'maximum_nights', 'number_of_reviews', 
]
vars_selected=['id', 'host_id', 'host_name', 'host_since', 'picture_url', 'listing_url', 'neighbourhood_cleansed', 
               'city', 'state', 'country', 'latitude', 'longitude',
               'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness',
               'review_scores_checkin', 'review_scores_communication',
               'review_scores_location', 'review_scores_value', 'reviews_per_month'
              ]

# %%
listings_sf[vars_selected]
# Out:
#             id    host_id          host_name  host_since  \
# 0          958       1169              Holly  2008-07-31
# 1         5858       8904   Philip And Tania  2009-03-02
# 2         7918      21994              Aaron  2009-06-17
# 3         8142      21994              Aaron  2009-06-17
# 4         8339      24215               Rosy  2009-07-02
# 5         8567      25601              Sandy  2009-07-14
# 6         8739       7149       Ivan & Wendy  2009-01-27
# 7         9225      29674                Gae  2009-08-04
# 8        10251      35199      Roman & Sarah  2009-08-31
# 9        10578      37049             Andrew  2009-09-08
# 10       10819      38836             Bernat  2009-09-15
# 11       10820      38836             Bernat  2009-09-15
# 12       10824      38836             Bernat  2009-09-15
# 13       10832      38836             Bernat  2009-09-15
# 14       12041      21994              Aaron  2009-06-17
# ...

# %%
listings_sf[vars_selected].shape
# Out:
# (6633, 20)

# %%
listings_sf[vars_selected].to_csv('listings_details.csv')
